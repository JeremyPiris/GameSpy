# %%
import pandas as pd
df = pd.read_csv('../data/gk_full_dataset.csv')

# %%
# Suppression des colonnes 'Unnamed'
df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace=True)


# Remplacement des NA par 0 
df['Date_sortie'].fillna(0, inplace=True)
df['Editeur'].fillna(0, inplace=True)
df['Licence'].fillna(0, inplace=True)


# Remplacement des NA de la colonne [0] par -1 et transformation en float
df.loc[df['0']=='-', '0'] = '-1'
df['0'].fillna('-1', inplace=True)
df['0'] = df['0'].astype('float')


# Remplacement des NA de la colonne [Note_GK] par les valeurs de la colonne [0]
# transformation en float
df['Note_GK'].fillna(df['0'], inplace=True)
df['Note_GK'] = df['Note_GK'].astype('float')


# Suppression de la colonne [0]
df.drop(['0'], axis=1, inplace=True)


# Transformation de la colonne [Date_note_GK] en format datetime
df['jour_test'] = df['Date_note_GK'].str.split(' ', expand=True).get(0)
df['mois_test'] = df['Date_note_GK'].str.split(' ', expand=True).get(1)
df['annee_test'] = df['Date_note_GK'].str.split(' ', expand=True).get(2)
df = df.replace(
    to_replace = ['janvier','février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre'],
    value = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12'])
df['Date_Test_GK'] = df['annee_test'].str.cat(df['mois_test'], sep='/').str.cat(df['jour_test'], sep='/')
df['Date_Test_GK'] = pd.to_datetime(df['Date_Test_GK'])

# et suppression des colonnes utilisées en stand-by 
df.drop(['Date_note_GK', 'jour_test', 'mois_test', 'annee_test'], axis=1, inplace=True)


# Récupération de la plateforme sur laquelle a été fait le test
df['Platform_test'] = df['Url'].str.split('/', expand=True).get(3)
df['Platform_test'] = df['Platform_test'].str.split('-', expand=True).get(1)
df['Platform_test'] = df['Platform_test'].str.split('.', expand=True).get(0)
df['Platform_test'] = df['Platform_test'].fillna('')
df['Platform_test'] = df['Platform_test'].apply(lambda x: str(x). upper())


# Récupération du nb dans la colonne [Nb_avis]
df['Nb_avis'] = df['Nb_avis'].apply(lambda x: x[:-5])
df['Nb_avis'] = df['Nb_avis'].astype('int')


# Renommage et repositionnement des colonnes notes
df['Note_Test_GK'] = df['Note_GK']
df['Note_Users'] = df['Note_joueurs']
df['Nb_Note_Users'] = df['Nb_avis']
df.drop(['Note_GK', 'Note_joueurs', 'Nb_avis'], axis=1, inplace=True)


# Explosion du dataset en fonction de la colonne [Platform]
df['Platform'] = df['Platform'].str.split('\n')
df = df.explode('Platform')

# Rajout de l'année de sortie
df['Annee_sortie'] = df['Date_sortie'].apply(lambda x: str(x)[-4:])
df['Annee_sortie'] = df['Annee_sortie'].replace(['évue'], ['0'])
df['Annee_sortie'] = df['Annee_sortie'].astype('int')

# %%
df.head(20)
# Out:
#                             Name  \
# 0              F.C. Manager 2007
# 0              F.C. Manager 2007
# 0              F.C. Manager 2007
# 1     Sonic Mega Collection Plus
# 1     Sonic Mega Collection Plus
# 1     Sonic Mega Collection Plus
# 1     Sonic Mega Collection Plus
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 2               Final Fantasy II
# 3  Call of Duty : Modern Warfare
# 3  Call of Duty : Modern Warfare
# 3  Call of Duty : Modern Warfare
# 4                      NI.BI.RU.
#
#                                                  Url  \
# 0   /jeux/f-c-manager-2007-3010002408/test-x360.html
# 0   /jeux/f-c-manager-2007-3010002408/test-x360.html
# 0   /jeux/f-c-manager-2007-3010002408/test-x360.html
# 1  /jeux/sonic-mega-collection-plus-3010001353/te...
# 1  /jeux/sonic-mega-collection-plus-3010001353/te...
# 1  /jeux/sonic-mega-collection-plus-3010001353/te...
# 1  /jeux/sonic-mega-collection-plus-3010001353/te...
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 2        /jeux/final-fantasy-ii-3010001572/test.html
# 3  /jeux/call-of-duty-modern-warfare-3050880667/t...
# 3  /jeux/call-of-duty-modern-warfare-3050880667/t...
# 3  /jeux/call-of-duty-modern-warfare-3050880667/t...
# 4                     /jeux/ni-bi-ru-69165/test.html
#
#                                         Genre        Date_sortie Platform  \
# 0  Gestion,                             Sport  22 septembre 2006       PC
# 0  Gestion,                             Sport  22 septembre 2006     X360
# 0  Gestion,                             Sport  22 septembre 2006      PS2
# 1                                 Compilation       21 mars 2003      NGC
# 1                                 Compilation       21 mars 2003      PS2
# 1                                 Compilation       21 mars 2003     XBOX
# 1                                 Compilation       21 mars 2003       PC
# 2                                Jeu de rôles                  0       PS
# 2                                Jeu de rôles                  0      NES
# 2                                Jeu de rôles                  0      PSP
# 2                                Jeu de rôles                  0      WSC
# 2                                Jeu de rôles                  0       CV
# 2                                Jeu de rôles                  0     CVWU
# 2                                Jeu de rôles                  0    CV3DS
# 2                                Jeu de rôles                  0      PSN
# 2                                Jeu de rôles                  0       iP
# 3                                         FPS    25 octobre 2019       PC
# 3                                         FPS    25 octobre 2019      PS4
# 3                                         FPS    25 octobre 2019     XONE
# 4                      Aventure-Point & click       11 mars 2005       PC
#
#                Editeur        Licence Date_Test_GK Platform_test  \
# 0          Codemasters   F.C. Manager   2006-10-05          X360
# 0          Codemasters   F.C. Manager   2006-10-05          X360
# 0          Codemasters   F.C. Manager   2006-10-05          X360
# 1                Atari          Sonic   2005-02-02           PS2
# 1                Atari          Sonic   2005-02-02           PS2
# 1                Atari          Sonic   2005-02-02           PS2
# 1                Atari          Sonic   2005-02-02           PS2
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 2           Squaresoft  Final Fantasy   2008-02-20
# 3  Activision Blizzard   Call of Duty   2019-10-29
# 3  Activision Blizzard   Call of Duty   2019-10-29
# 3  Activision Blizzard   Call of Duty   2019-10-29
# 4         Future Games              0   2005-03-11
#
#    Note_Test_GK  Note_Users  Nb_Note_Users  Annee_sortie
# 0           5.0         6.0              1          2006
# 0           5.0         6.0              1          2006
# 0           5.0         6.0              1          2006
# 1           6.0         6.9             34          2003
# 1           6.0         6.9             34          2003
# 1           6.0         6.9             34          2003
# 1           6.0         6.9             34          2003
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 2           6.0         7.0             23             0
# 3           8.0         6.0             27          2019
# 3           8.0         6.0             27          2019
# 3           8.0         6.0             27          2019
# 4           5.0         0.0              0          2005

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26917 entries, 0 to 8623
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26917 non-null  object
#  1   Url            26917 non-null  object
#  2   Genre          26903 non-null  object
#  3   Date_sortie    26917 non-null  object
#  4   Platform       26917 non-null  object
#  5   Editeur        26917 non-null  object
#  6   Licence        26917 non-null  object
#  7   Date_Test_GK   26917 non-null  datetime64[ns]
#  8   Platform_test  26917 non-null  object
#  9   Note_Test_GK   26917 non-null  float64
#  10  Note_Users     26917 non-null  float64
#  11  Nb_Note_Users  26917 non-null  int64
#  12  Annee_sortie   26917 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 2.9+ MB

# %%
df['Genre'].unique()
# Out:
# array(['Gestion,                             Sport', 'Compilation',
#        'Jeu de rôles', 'FPS', 'Aventure-Point & click', 'Sport',
#        'Stratégie temps réel', 'Action,                             FPS',
#        'Action-Aventure,                             Plates-formes',
#        'TPS',
#        'Jeu de rôles,                             Stratégie temps réel',
#        'Stratégie tour par tour', 'Puzzle Game', "Jeu d'adresse",
#        'Simulation de vie', 'Action-Aventure',
#        'Tactique,                             TPS', 'Action-RPG',
#        'Action,                             TPS',
#        'Action,                             Course', 'MOBA', 'Musique',
#        'Infiltration', 'Réflexion',
#        'Action-Aventure,                             Roguelike/Roguelite',
#        'Action', 'Aventure,                             Inclassable',
#        'Course', 'Inclassable', 'Plates-formes',
#        'Réflexion,                             Inclassable',
#        'Action,                             Wargame',
#        'Action,                             Plates-formes',
#        'Action,                             Réflexion',
#        'Jeu de rôles,                             Jeu de cartes',
#        'Simulation,                             Course', 'Aventure',
#        'Gestion', 'Visual novel',
#        'Aventure,                             Plates-formes',
#        'Action,                             Stratégie temps réel',
#        'Hack and slash',
#        'Jeu de rôles,                             Tactique',
#        'Gestion,                             Stratégie temps réel',
#        'Aventure,                             Réflexion',
#        'Jeu de cartes,                             Roguelike/Roguelite',
#        'Aventure,                             Jeu de rôles', 'Combat',
#        "Beat'em up",
#        'Plates-formes,                             Réflexion',
#        'Action,                             Puzzle Game', 'Jeu de tir',
#        'FPS,                             Tactique',
#        'Stratégie tour par tour,                             Sport',
#        'Action,                             Jeu de rôles', 'Party game',
#        'Action,                             Roguelike/Roguelite',
#        'Stratégie tour par tour,                             Simulation',
#        'Réflexion,                             Course',
#        'Action,                             Action-Aventure,                             Plates-formes',
#        'Réflexion,                             Stratégie temps réel',
#        'Stratégie tour par tour,                             Gestion',
#        'Plates-formes,                             Puzzle Game',
#        'Action,                             Action-Aventure',
#        'Action,                             Combat',
#        'Action,                             Action-Aventure,                             Réflexion',
#        'Wargame,                             Stratégie temps réel',
#        'Bande annonce', "Shoot'em up",
#        'Aventure-Point & click,                             Action-Aventure',
#        'Action,                             Sport',
#        'Jeu de société, hasard', 'Flipper',
#        'Plates-formes,                             Aventure narrative',
#        'Stratégie tour par tour,                             Stratégie temps réel',
#        'Ludo-éducatif',
#        'Stratégie tour par tour,                             Tactique',
#        'Action,                             FPS,                             Tactique',
#        'FPS,                             Stratégie temps réel',
#        'Action,                             Infiltration',
#        'Gestion,                             Simulation',
#        'Action,                             Tactique',
#        'Sport,                             Tactique', 'Wargame',
#        'Simulation',
#        'Jeu de rôles,                             Puzzle Game',
#        'Action-Aventure,                             Jeu de survie',
#        'Stratégie tour par tour,                             Wargame',
#        nan, 'Jeu de rôles,                             Combat',
#        'Action,                             Stratégie tour par tour',
#        'Action,                             Tactique,                             TPS',
#        'Action-Aventure,                             Jeu de rôles',
#        'Jeu de cartes',
#        'Jeu de rôles,                             Gestion',
#        'Infiltration,                             TPS',
#        "Jeu de rôles,                             Beat'em up",
#        'FPS,                             Jeu de rôles',
#        'Aventure narrative', 'Tactique',
#        'Action,                             Gestion',
#        "Shoot'em up,                             Puzzle Game",
#        'FPS,                             Simulation',
#        'Action-RPG,                             Hack and slash',
#        'Simulation,                             Exploration',
#        'Plates-formes,                             Jeu de tir',
#        'Action,                             Plates-formes,                             Réflexion',
#        'Action-Aventure,                             FPS',
#        'FPS,                             Infiltration',
#        'Gestion,                             Course',
#        'Aventure,                             Combat',
#        'Aventure,                             Stratégie temps réel',
#        'Jeu de cartes,                             Infiltration',
#        'Compilation,                             Action-RPG',
#        'Aventure-Point & click,                             Jeu de survie',
#        'Construction,                             Jeu de survie',
#        'Réflexion,                             Puzzle Game',
#        'Stratégie temps réel,                             Aventure narrative',
#        'Stratégie tour par tour,                             Jeu de rôles',
#        'FPS,                             Puzzle Game',
#        'Jeu de cartes,                             Action-RPG',
#        'Aventure-Point & click,                             Exploration',
#        'Jeu de rôles,                             MMORPG',
#        'Jeu de tir,                             Musique',
#        'Puzzle Game,                             Aventure narrative',
#        "FPS,                             Shoot'em up",
#        'Sport,                             Party game',
#        'Réflexion,                             Aventure narrative',
#        'Tactique,                             Infiltration',
#        'Gestion,                             Musique',
#        'Action,                             Aventure,                             Plates-formes,                             Réflexion',
#        'Aventure,                             Course',
#        'Jeu de rôles,                             Plates-formes',
#        'Action-Aventure,                             Réflexion',
#        'Plates-formes,                             Roguelike/Roguelite',
#        'Action,                             Aventure',
#        'Aventure,                             Simulation de vie',
#        'Tactique,                             Roguelike/Roguelite',
#        'Action-Aventure,                             Compilation',
#        'MMORPG', 'FPS,                             Plates-formes',
#        'Gestion,                             Simulation de vie',
#        'Action-RPG,                             Roguelike/Roguelite',
#        'Action,                             Plates-formes,                             Roguelike/Roguelite',
#        'Gestion,                             Combat',
#        'Action,                             Jeu de tir',
#        'TPS,                             Battle Royale',
#        'Jeu de rôles,                             Roguelike/Roguelite',
#        "Beat'em up,                             Aventure narrative",
#        'Combat,                             MMORPG',
#        'Action,                             Party game',
#        'Action-Aventure,                             Party game',
#        'Compilation,                             Visual novel',
#        'Action,                             Stratégie temps réel,                             Roguelike/Roguelite',
#        'Jeu de survie',
#        'Plates-formes,                             Course',
#        'Roguelike/Roguelite', 'Sport,                             Combat',
#        'Stratégie tour par tour,                             Combat',
#        'Musique,                             Roguelike/Roguelite',
#        'Action-Aventure,                             Jeu de cartes',
#        'Jeu de rôles,                             Construction',
#        'Aventure,                             Tactique',
#        'Jeu de rôles,                             Réflexion',
#        'Stratégie temps réel,                             Ludo-éducatif',
#        "Action,                             Shoot'em up",
#        'Gestion,                             Réflexion',
#        'TPS,                             Jeu de survie',
#        'Tactique,                             Aventure narrative,                             Roguelike/Roguelite',
#        'Action,                             Musique', 'Vidéo Gamekult',
#        'FPS,                             Réflexion',
#        'Action,                             Simulation',
#        'Tactique,                             Course',
#        'Plates-formes,                             Musique',
#        'Action-Aventure,                             Exploration',
#        "Action,                             Beat'em up",
#        'Aventure,                             Flipper,                             Exploration',
#        'Gestion,                             Construction',
#        'Action,                             Jeu de survie',
#        'Action-Aventure,                             Gestion',
#        'Aventure,                             Ludo-éducatif',
#        'Aventure,                             Puzzle Game',
#        'Action-Aventure,                             Course',
#        'Aventure,                             Compilation',
#        'Sport,                             Simulation',
#        'Aventure,                             Action-Aventure',
#        'Action-Aventure,                             Inclassable',
#        'Action,                             Plates-formes,                             Party game',
#        'Puzzle Game,                             Exploration',
#        'Jeu de tir,                             TPS',
#        'Aventure-Point & click,                             Réflexion',
#        'Inclassable,                             Course',
#        'Stratégie tour par tour,                             Jeu de cartes',
#        'Jeu de rôles,                             Jeu de tir',
#        'Stratégie tour par tour,                             Roguelike/Roguelite',
#        "Plates-formes,                             Jeu d'adresse",
#        'Aventure,                             Visual novel',
#        'Action-Aventure,                             Infiltration',
#        'Stratégie temps réel,                             Jeu de cartes',
#        'Gestion,                             Jeu de survie',
#        'Ludo-culturel', 'Aventure,                             FPS',
#        'Réflexion,                             Simulation',
#        'Aventure,                             Jeu de survie',
#        'TPS,                             Roguelike/Roguelite',
#        "Course,                             Jeu d'adresse",
#        'Plates-formes,                             Course,                             Compilation',
#        'Aventure,                             Infiltration',
#        'FPS,                             Battle Royale',
#        'Gestion,                             Tactique',
#        'Tactique,                             Stratégie temps réel',
#        "Puzzle Game,                             Jeu d'adresse",
#        'Aventure,                             Musique',
#        'Stratégie tour par tour,                             Jeu de rôles,                             Roguelike/Roguelite',
#        'Sport,                             Course',
#        'Jeu de survie,                             Exploration',
#        'FPS,                             Jeu de survie',
#        'Infiltration,                             Aventure narrative',
#        'Action-Aventure,                             TPS',
#        'Plates-formes,                             TPS', 'Construction',
#        'FPS,                             Inclassable',
#        'Action-RPG,                             Jeu de survie',
#        'Réflexion,                             Exploration',
#        'Action,                             Action-Aventure,                             Course',
#        'Stratégie temps réel,                             Roguelike/Roguelite',
#        'Kit de développement',
#        'Aventure,                             Flipper',
#        'Infiltration,                             Jeu de survie',
#        'TPS,                             Action-RPG',
#        "Réflexion,                             Jeu d'adresse",
#        'Action,                             Plates-formes,                             Course',
#        "Action-Aventure,                             Beat'em up",
#        'Plates-formes,                             Combat',
#        'Jeu de rôles,                             TPS',
#        'Plates-formes,                             Inclassable',
#        'Aventure-Point & click,                             Puzzle Game',
#        'Stratégie temps réel,                             Simulation',
#        'Réflexion,                             Infiltration',
#        'Gestion,                             Roguelike/Roguelite',
#        "Combat,                             Shoot'em up",
#        'Aventure,                             Aventure-Point & click',
#        "Action,                             Plates-formes,                             Beat'em up",
#        'Plates-formes,                             Infiltration',
#        'Jeu de rôles,                             Exploration',
#        'Roguelike/Roguelite,                             Exploration',
#        'Réflexion,                             Roguelike/Roguelite',
#        'Simulation,                             Emulateur,                             Course',
#        'Visual novel,                             Aventure narrative',
#        'Exploration',
#        'Plates-formes,                             Party game',
#        "Stratégie temps réel,                             Beat'em up",
#        'Action,                             Aventure,                             Infiltration',
#        'Aventure narrative,                             Exploration',
#        'Action-Aventure,                             Construction',
#        'Aventure,                             Simulation',
#        'Aventure,                             Gestion',
#        'FPS,                             Jeu de tir',
#        'Action-Aventure,                             Jeu de tir',
#        'Stratégie tour par tour,                             Action-RPG'],
#       dtype=object)
